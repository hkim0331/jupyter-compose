# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(-10,10,0.1)

# %%
y = np.sin(x)+2*np.sin(3*x)

# %%
plt.plot(x,y)
plt.plot(x,np.cos(x))

# %%
fig,ax = plt.subplots()
ax.plot([1,2,3,4],[3,4,1,2])

# %%
ax.plot([1,2,3,4],[3,4,2,1])
plt.show()

# %%
plt.show()
